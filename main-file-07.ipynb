# %% [markdown]
# # **Experiment 07 (Stratified K-fold cross validation)**
#
# ## **Name: Fahim Shahriar**
# ### Github: https://github.com/FahimS45
#
# ### Dataset description: https://archive.ics.uci.edu/dataset/2/adult
# ### Dataset link: https://www.kaggle.com/datasets/wenruliu/adult-income-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks, RandomUnderSampler

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, precision_score, recall_score, f1_score


# Ensure matplotlib inline plotting for Jupyter Notebooks
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
data = pd.read_csv('adult.csv', na_values="?", skipinitialspace=True)

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18               NaN  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29               NaN  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                NaN      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                NaN      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# 48835  Married-civ-spouse    Exec-managerial        Husband
# 48836       Never-married    Protective-serv  Not-in-family
# 48837  Married-civ-spouse       Tech-support           Wife
# 48838  Married-civ-spouse  Machine-op-inspct        Husband
# 48839             Widowed       Adm-clerical      Unmarried
# 48840       Never-married       Adm-clerical      Own-child
# 48841  Married-civ-spouse    Exec-managerial           Wife
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 48832  Amer-Indian-Eskimo    Male             0             0              40
# 48833               White    Male             0             0              45
# 48834  Asian-Pac-Islander    Male             0             0              11
# 48835               White    Male             0             0              40
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              38
# 48838               White    Male             0             0              40
# 48839               White  Female             0             0              40
# 48840               White    Male             0             0              20
# 48841               White  Female         15024             0              40
#
#       native-country income
# 48832  United-States  <=50K
# 48833  United-States  <=50K
# 48834         Taiwan  <=50K
# 48835  United-States   >50K
# 48836  United-States  <=50K
# 48837  United-States  <=50K
# 48838  United-States   >50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       46033 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   47985 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.nunique()
# Out:
# age                   74
# workclass              8
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            14
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        41
# income                 2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
def null_percentage (df):

    df_len = df.shape[0]
    columns = df.columns
    total_null_count = 0

    for each in columns:
        null_count = df[each].isnull().sum()
        if null_count != 0.0:
            null_per = (df[each].isnull().sum() / df_len) * 100
            print(f'Null value percentage in {each} is : {null_per: .2f}')
            total_null_count = total_null_count + null_count
            
    if total_null_count == 0:
        print(f'No null value exist.')

# %%
null_percentage(data)
# Out:
# Null value percentage in workclass is :  5.73
# Null value percentage in occupation is :  5.75
# Null value percentage in native-country is :  1.75

# %%
def cat_cols(df):

    categorical_cols = df.select_dtypes(include=['object']).columns
    total_cat_cols = len(categorical_cols)
    total_cols = df.shape[1]

    if total_cat_cols != 0: 
        print(f'Total categorical column {total_cat_cols} out of {total_cols} and they are as follows: ')

        for each in categorical_cols:
            print(each)

        for each in categorical_cols:
            unique_vals = df[each].unique()
            print(f'Feature {each} has {len(unique_vals)} unique values which are: {unique_vals}\n')

# %%
cat_cols(data)
# Out:
# Total categorical column 9 out of 15 and they are as follows:
# workclass
# education
# marital-status
# occupation
# relationship
# race
# gender
# native-country
# income
# Feature workclass has 9 unique values which are: ['Private' 'Local-gov' nan 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# Feature education has 16 unique values which are: ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
# Feature marital-status has 7 unique values which are: ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# Feature occupation has 15 unique values which are: ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' nan
#  'Other-service' 'Prof-specialty' 'Craft-repair' 'Adm-clerical'
#  'Exec-managerial' 'Tech-support' 'Sales' 'Priv-house-serv'
#  'Transport-moving' 'Handlers-cleaners' 'Armed-Forces']
#
# Feature relationship has 6 unique values which are: ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
#
# Feature race has 5 unique values which are: ['Black' 'White' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
#
# Feature gender has 2 unique values which are: ['Male' 'Female']
#
# Feature native-country has 42 unique values which are: ['United-States' nan 'Peru' 'Guatemala' 'Mexico' 'Dominican-Republic'
#  'Ireland' 'Germany' 'Philippines' 'Thailand' 'Haiti' 'El-Salvador'
#  'Puerto-Rico' 'Vietnam' 'South' 'Columbia' 'Japan' 'India' 'Cambodia'
#  'Poland' 'Laos' 'England' 'Cuba' 'Taiwan' 'Italy' 'Canada' 'Portugal'
#  'China' 'Nicaragua' 'Honduras' 'Iran' 'Scotland' 'Jamaica' 'Ecuador'
#  'Yugoslavia' 'Hungary' 'Hong' 'Greece' 'Trinadad&Tobago'
#  'Outlying-US(Guam-USVI-etc)' 'France' 'Holand-Netherlands']
#
# Feature income has 2 unique values which are: ['<=50K' '>50K']

# %% [markdown]
# ### **Apply Label encoder**

# %%
df = data.copy()

label_encoder = LabelEncoder()

# Function to apply label encoding ignoring missing values
def label_encode_column(column):

    placeholder = 'missing'
    temp_col = column.fillna(placeholder)
    
    encoded_col = label_encoder.fit_transform(temp_col)
    
    encoded_col = pd.Series(encoded_col, index=column.index)
    encoded_col[column.isna()] = np.nan
    
    return encoded_col

for column in df.columns:
    df[column] = label_encode_column(df[column])

df
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0        8        3.0   19329          1                6               4
# 1       21        3.0    4212         11                8               2
# 2       11        1.0   25340          7               11               2
# 3       27        3.0   11201         15                9               2
# 4        1        NaN    5411         15                9               4
# ...    ...        ...     ...        ...              ...             ...
# 48837   10        3.0   21582          7               11               2
# 48838   23        3.0   10584         11                8               2
# 48839   41        3.0   10316         11                8               6
# 48840    5        3.0   16813         11                8               4
# 48841   35        4.0   23321         11                8               2
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0             6.0             3     2       1             0             0
# 1             4.0             0     4       1             0             0
# 2            10.0             0     4       1             0             0
# 3             6.0             0     2       1            98             0
# 4             NaN             3     4       0             0             0
# ...           ...           ...   ...     ...           ...           ...
# 48837        12.0             5     4       0             0             0
# 48838         6.0             0     4       1             0             0
# 48839         0.0             4     4       0             0             0
# 48840         0.0             3     4       1             0             0
# 48841         3.0             5     4       0           112             0
#
#        hours-per-week  native-country  income
# 0                  39            38.0       0
# 1                  49            38.0       0
# 2                  39            38.0       1
# 3                  39            38.0       1
# 4                  29            38.0       0
# ...               ...             ...     ...
# 48837              37            38.0       0
# 48838              39            38.0       1
# 48839              39            38.0       0
# 48840              19            38.0       0
# 48841              39            38.0       1
#
# [48842 rows x 15 columns]

# %% [markdown]
# ### **Data Visualization**

# %%
# Histogram for age
plt.figure(figsize=(12, 6))
sns.histplot(df['age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Bar chart for education level
plt.figure(figsize=(12, 6))
sns.countplot(y='education', data=df, order = df['education'].value_counts().index)
plt.title('Education Level Distribution')
plt.xlabel('Counts')
plt.ylabel('Education Level')
plt.show()

# %%
# Scatter plot for age vs hours-per-week
plt.figure(figsize=(12, 6))
sns.scatterplot(x='age', y='hours-per-week', data=df, hue='income', alpha=0.6)

# Customize the legend
plt.legend(title='Income', loc='upper left', bbox_to_anchor=(1, 1))

plt.title('Age vs. Hours-per-week')
plt.xlabel('Age')
plt.ylabel('Hours-per-week')
plt.show()

# %%
# Pairwise plot -> multi-variate
# Selecting a subset of features for clarity
subset_data = df[['age', 'gender', 'hours-per-week', 'income']]

# Pair plot
plt.figure(figsize=(12, 6))
sns.pairplot(subset_data, hue='income', diag_kind='kde', plot_kws={'alpha':0.6, 's':80, 'edgecolor':'k'}, size=2)
plt.show()

# %%
# Visualize null values in bar plot
def null_values_bar_plot(df):

    missing_values = df.isnull().sum()
    plt.figure(figsize=(12, 6))

    ax = sns.barplot(x=missing_values.index, y=missing_values.values, palette="viridis")

    # Customize the plot
    plt.xlabel('Features')
    plt.ylabel('Missing Values Count')
    plt.title('Missing Values Count per Feature')

    # Angle the x-axis tick labels
    plt.xticks(rotation=45)  # Rotate labels to 45 degrees for better readability

    # Show the plot
    plt.tight_layout()
    plt.show()

null_values_bar_plot(df)

# %% [markdown]
# ### **Train Test Split**

# %%
X = df.iloc[:, 0:14]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
print(f'Shape of X_train: {X_train.shape}')
print(f'Shape of X_test: {X_test.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_test: {y_test.shape}')
# Out:
# Shape of X_train: (34189, 14)
# Shape of X_test: (14653, 14)
# Shape of y_train: (34189,)
# Shape of y_test: (14653,)

# %% [markdown]
# ### **Imputing missing values with mean**

# %%
# Imputation with mean
imputer_ = SimpleImputer(strategy='mean')

X_train_imputed = imputer_.fit_transform(X_train)
X_test_imputed = imputer_.transform(X_test)

column_names = ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 
                'marital-status', 'occupation', 'relationship', 'race', 
                'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 
                'native-country']

X_train_imputed = pd.DataFrame(X_train_imputed, columns=column_names)
X_test_imputed = pd.DataFrame(X_test_imputed, columns=column_names)

# %% [markdown]
# ### **Outliers Handling**

# %% [markdown]
# Outliers detection

# %%
def plot_feature_distributions(df):

    numeric_features = df.select_dtypes(include=['number']).columns
    
    for feature in numeric_features:
        plt.figure(figsize=(12, 6))
        
        # Original distribution plot
        plt.subplot(2, 2, 1)
        sns.distplot(df[feature], kde=True, hist=True)
        plt.title(f'Distribution of {feature}')
        
        # Original boxplot
        plt.subplot(2, 2, 2)
        sns.boxplot(df[feature])
        plt.title(f'Boxplot of {feature}')

        plt.tight_layout()
        plt.show()

plot_feature_distributions(X_train_imputed)

# %% [markdown]
# Outliers removal: replacing outliers with the mean for each column

# %%
def outlier_replacement_with_mean(df):

    data = df

    for col in data.columns:
        mean = data[col].mean()
        sd = data[col].std()
        data[col].mask(data[col] > mean+(2*sd), mean, inplace=True)
        data[col].mask(data[col] < mean-(2*sd), mean, inplace=True)

# %%
outlier_replacement_with_mean(X_train_imputed)

# %%
# After handling outliers
plot_feature_distributions(X_train_imputed)

# %% [markdown]
# ### **Feature Selection**

# %% [markdown]
# Dropping columns using pearson correlation

# %%
# Pearson's Correlation Coefficient

corr = X_train.corr()
mask1 = np.triu(np.ones_like(corr, dtype=bool))
mask2 = np.tril(np.ones_like(corr, dtype=bool))
plt.figure(figsize = (12,6))
sns.heatmap(corr, annot = True, cmap = "seismic", mask = mask2);

# %%
# Correlation heatmap
plt.figure(figsize=(12, 6))
correlation_matrix = X_train.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Removing features that are highly correlated with another features with a threshold of >=80

def correlation(df, threshold):
    col_corr = set() # Set of all the names of the redundant columns
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) >= threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.8) # Threshold as 80% 
print(len(corr_features))
print(corr_features)
# Out:
# 0
# set()

# %% [markdown]
# Now, let's use Recursive Feature Elimination through Cross Validation (RFECV) to select the most valuable features

# %%
from sklearn.feature_selection import RFECV

# Explore RFECV technique 
lr = LogisticRegression(solver='liblinear', random_state=42)

rfecv = RFECV(estimator=lr, min_features_to_select=5, step=1, cv=5)
rfecv.fit(X_train_imputed, y_train)

X_train_sub = rfecv.transform(X_train_imputed)

selected_features = df.columns[:-1][rfecv.support_]
print(f'Selected {len(selected_features)} features through RFECVare: {selected_features}')
# Out:
# Selected 12 features through RFECVare: Index(['age', 'workclass', 'education', 'educational-num', 'marital-status',
#        'relationship', 'race', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country'],
#       dtype='object')

# %% [markdown]
# Later in this notebook we will do RFECV to obtain optimum number of features as part of our pipeline

# %% [markdown]
# ### **Pipeline of all the models and operations**

# %%
# Define pipelines for different models
pipelines = {
    'Logistic Regression': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LogisticRegression(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)), 
        ('classifier', LogisticRegression(random_state=42))
    ]),
    'Support Vector Classifier': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LogisticRegression(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)), 
        ('classifier', SVC(random_state=42))
    ]),
    'Decision Tree': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=DecisionTreeClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', DecisionTreeClassifier(random_state=42))
    ]),
    'Random Forest': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=RandomForestClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),  
        ('classifier', RandomForestClassifier(random_state=42))
    ]),
    'AdaBoost': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=AdaBoostClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', AdaBoostClassifier(random_state=42))
    ]),
    'GradientBoost': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=GradientBoostingClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', GradientBoostingClassifier(random_state=42))
    ]),
    'XGBoost': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=XGBClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', XGBClassifier(random_state=42))
    ]),
    'LightGBM': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LGBMClassifier(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', LGBMClassifier(random_state=42))
    ]),
    'Naive Bayes': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LogisticRegression(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', GaussianNB())
    ]),
    'KNN': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LogisticRegression(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('classifier', KNeighborsClassifier(n_neighbors=189))
    ]),
    'Bagging': Pipeline([
        ('scaler', StandardScaler()),
        ('feature_selection', RFECV(estimator=LogisticRegression(random_state=42), step=1, cv=5, min_features_to_select=1, scoring='accuracy', n_jobs=-1)),
        ('BaggingClassifier', BaggingClassifier(random_state=42))
    ])
}

# %%
from sklearn import set_config
set_config(display='diagram')
pipelines
# Out:
# {'Logistic Regression': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LogisticRegression(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', LogisticRegression(random_state=42))]),
#  'Support Vector Classifier': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LogisticRegression(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', SVC(random_state=42))]),
#  'Decision Tree': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', DecisionTreeClassifier(random_state=42))]),
#  'Random Forest': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', RandomForestClassifier(random_state=42))]),
#  'AdaBoost': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', AdaBoostClassifier(random_state=42))]),
#  'GradientBoost': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5,
#                         estimator=GradientBoostingClassifier(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', GradientBoostingClassifier(random_state=42))]),
#  'XGBoost': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5,
#                         estimator=XGBClassifier(base_score=None, booster=None,
#                                                 callbacks=None,
#                                                 colsample_bylevel=None,
#                                                 colsample_bynode=None,
#                                                 colsample_bytree=None,
#                                                 device=None,
#                                                 early_stopping_rounds=None,
#                                                 enable_categorical=False,
#                                                 eval_metric=None,
#                                                 feature_types=None, gamma=None,
#                                                 grow_policy=None,
#                                                 importance_...
#                                 feature_types=None, gamma=None, grow_policy=None,
#                                 importance_type=None,
#                                 interaction_constraints=None, learning_rate=None,
#                                 max_bin=None, max_cat_threshold=None,
#                                 max_cat_to_onehot=None, max_delta_step=None,
#                                 max_depth=None, max_leaves=None,
#                                 min_child_weight=None, missing=nan,
#                                 monotone_constraints=None, multi_strategy=None,
#                                 n_estimators=None, n_jobs=None,
#                                 num_parallel_tree=None, random_state=42, ...))]),
#  'LightGBM': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LGBMClassifier(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', LGBMClassifier(random_state=42))]),
#  'Naive Bayes': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LogisticRegression(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', GaussianNB())]),
#  'KNN': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LogisticRegression(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('classifier', KNeighborsClassifier(n_neighbors=189))]),
#  'Bagging': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('feature_selection',
#                   RFECV(cv=5, estimator=LogisticRegression(random_state=42),
#                         n_jobs=-1, scoring='accuracy')),
#                  ('BaggingClassifier', BaggingClassifier(random_state=42))])}

# %% [markdown]
# ### **Stratified K-fold Cross Validation**

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=10)

# %%
# Combine the training and test datasets to apply cross-validation
X = np.vstack((X_train_imputed, X_test_imputed))
y = np.concatenate((y_train, y_test))

# %%
metrics = {
    'Accuracy': accuracy_score,
    'Precision': precision_score,
    'Recall': recall_score,
    'F1 Score': f1_score
}

results = {metric: {} for metric in metrics}

# Train and evaluate each pipeline using StratifiedKFold
for model_name, pipeline in pipelines.items():
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    k = 1
    
    for train_index, test_index in skf.split(X, y):
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        pipeline.fit(X_train_fold, y_train_fold)
        y_pred = pipeline.predict(X_test_fold)
        selected_features = df.columns[:-1][pipeline.named_steps['feature_selection'].support_]

        print(f'For {model_name} model, {len(selected_features)} features have been selected in fold {k} where \nClassification Report is :\n {classification_report(y_test_fold, y_pred)}')
        print(f'Confusion matrix in fold {k}:\n {confusion_matrix(y_test_fold, y_pred)}')
        k += 1

        accuracies.append(accuracy_score(y_test_fold, y_pred))
        precisions.append(precision_score(y_test_fold, y_pred, average='weighted'))
        recalls.append(recall_score(y_test_fold, y_pred, average='weighted'))
        f1_scores.append(f1_score(y_test_fold, y_pred, average='weighted'))
        

    # Print average metrics over all folds
    print(f"{model_name} Average Accuracy: {np.mean(accuracies):.2f}")
    print(f"{model_name} Average Precision: {np.mean(precisions):.2f}")
    print(f"{model_name} Average Recall: {np.mean(recalls):.2f}")
    print(f"{model_name} Average F1 Score: {np.mean(f1_scores):.2f}\n")


    results['Accuracy'][model_name] = np.mean(accuracies)
    results['Precision'][model_name] = np.mean(precisions)
    results['Recall'][model_name] = np.mean(recalls)
    results['F1 Score'][model_name] = np.mean(f1_scores)

    print('----------------------------------------------------------------------------')
# Out:
# For Logistic Regression model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3716
#            1       0.68      0.39      0.49      1169
#
#     accuracy                           0.81      4885
#    macro avg       0.75      0.66      0.69      4885
# weighted avg       0.79      0.81      0.79      4885
#
# Confusion matrix in fold 1:
#  [[3501  215]
#  [ 717  452]]
# For Logistic Regression model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88      3716
#            1       0.68      0.35      0.46      1169
#
#     accuracy                           0.81      4885
#    macro avg       0.75      0.65      0.67      4885
# weighted avg       0.79      0.81      0.78      4885
#
# Confusion matrix in fold 2:
#  [[3521  195]
#  [ 756  413]]
# For Logistic Regression model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3716
#            1       0.67      0.39      0.50      1168
#
#     accuracy                           0.81      4884
#    macro avg       0.75      0.67      0.69      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 3:
#  [[3490  226]
#  [ 709  459]]
# For Logistic Regression model, 12 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      3716
#            1       0.69      0.37      0.48      1168
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.66      0.68      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 4:
#  [[3526  190]
#  [ 741  427]]
# For Logistic Regression model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3716
#            1       0.64      0.37      0.47      1168
#
#     accuracy                           0.80      4884
#    macro avg       0.73      0.65      0.67      4884
# weighted avg       0.78      0.80      0.78      4884
#
# Confusion matrix in fold 5:
#  [[3476  240]
#  [ 737  431]]
# For Logistic Regression model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      3715
#            1       0.69      0.39      0.50      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.67      0.69      4884
# weighted avg       0.80      0.81      0.79      4884
#
# Confusion matrix in fold 6:
#  [[3514  201]
#  [ 718  451]]
# For Logistic Regression model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      3715
#            1       0.69      0.36      0.48      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.66      0.68      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 7:
#  [[3523  192]
#  [ 743  426]]
# For Logistic Regression model, 7 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      3715
#            1       0.65      0.51      0.57      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.75      0.71      0.73      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 8:
#  [[3391  324]
#  [ 575  594]]
# For Logistic Regression model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      3715
#            1       0.67      0.53      0.59      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.72      0.74      4884
# weighted avg       0.81      0.82      0.82      4884
#
# Confusion matrix in fold 9:
#  [[3412  303]
#  [ 555  614]]
# For Logistic Regression model, 5 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      3715
#            1       0.68      0.51      0.58      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.72      0.74      4884
# weighted avg       0.81      0.83      0.82      4884
#
# Confusion matrix in fold 10:
#  [[3432  283]
#  [ 571  598]]
# Logistic Regression Average Accuracy: 0.81
# Logistic Regression Average Precision: 0.80
# Logistic Regression Average Recall: 0.81
# Logistic Regression Average F1 Score: 0.79
#
# ----------------------------------------------------------------------------
# For Support Vector Classifier model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89      3716
#            1       0.74      0.45      0.56      1169
#
#     accuracy                           0.83      4885
#    macro avg       0.79      0.70      0.73      4885
# weighted avg       0.82      0.83      0.82      4885
#
# Confusion matrix in fold 1:
#  [[3526  190]
#  [ 638  531]]
# For Support Vector Classifier model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      3716
#            1       0.74      0.45      0.56      1169
#
#     accuracy                           0.83      4885
#    macro avg       0.79      0.70      0.73      4885
# weighted avg       0.82      0.83      0.82      4885
#
# Confusion matrix in fold 2:
#  [[3530  186]
#  [ 641  528]]
# For Support Vector Classifier model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90      3716
#            1       0.73      0.47      0.57      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.79      0.71      0.73      4884
# weighted avg       0.82      0.83      0.82      4884
#
# Confusion matrix in fold 3:
#  [[3509  207]
#  [ 616  552]]
# For Support Vector Classifier model, 12 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      3716
#            1       0.75      0.44      0.56      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.80      0.70      0.73      4884
# weighted avg       0.82      0.83      0.82      4884
#
# Confusion matrix in fold 4:
#  [[3547  169]
#  [ 649  519]]
# For Support Vector Classifier model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3716
#            1       0.69      0.43      0.53      1168
#
#     accuracy                           0.82      4884
#    macro avg       0.77      0.69      0.71      4884
# weighted avg       0.80      0.82      0.80      4884
#
# Confusion matrix in fold 5:
#  [[3491  225]
#  [ 663  505]]
# For Support Vector Classifier model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3715
#            1       0.69      0.44      0.54      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.77      0.69      0.71      4884
# weighted avg       0.80      0.82      0.80      4884
#
# Confusion matrix in fold 6:
#  [[3484  231]
#  [ 657  512]]
# For Support Vector Classifier model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      3715
#            1       0.75      0.46      0.57      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.80      0.70      0.73      4884
# weighted avg       0.82      0.83      0.82      4884
#
# Confusion matrix in fold 7:
#  [[3534  181]
#  [ 636  533]]
# For Support Vector Classifier model, 7 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      3715
#            1       0.75      0.53      0.62      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.81      0.74      0.76      4884
# weighted avg       0.84      0.84      0.83      4884
#
# Confusion matrix in fold 8:
#  [[3508  207]
#  [ 554  615]]
# For Support Vector Classifier model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      3715
#            1       0.76      0.52      0.62      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.81      0.73      0.76      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 9:
#  [[3528  187]
#  [ 561  608]]
# For Support Vector Classifier model, 5 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      3715
#            1       0.77      0.50      0.60      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.81      0.72      0.75      4884
# weighted avg       0.84      0.84      0.83      4884
#
# Confusion matrix in fold 10:
#  [[3537  178]
#  [ 587  582]]
# Support Vector Classifier Average Accuracy: 0.83
# Support Vector Classifier Average Precision: 0.82
# Support Vector Classifier Average Recall: 0.83
# Support Vector Classifier Average F1 Score: 0.82
#
# ----------------------------------------------------------------------------
# For Decision Tree model, 11 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      3716
#            1       0.57      0.59      0.58      1169
#
#     accuracy                           0.79      4885
#    macro avg       0.72      0.72      0.72      4885
# weighted avg       0.80      0.79      0.80      4885
#
# Confusion matrix in fold 1:
#  [[3195  521]
#  [ 483  686]]
# For Decision Tree model, 14 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      3716
#            1       0.59      0.62      0.61      1169
#
#     accuracy                           0.81      4885
#    macro avg       0.74      0.74      0.74      4885
# weighted avg       0.81      0.81      0.81      4885
#
# Confusion matrix in fold 2:
#  [[3220  496]
#  [ 446  723]]
# For Decision Tree model, 11 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      3716
#            1       0.57      0.57      0.57      1168
#
#     accuracy                           0.79      4884
#    macro avg       0.72      0.72      0.72      4884
# weighted avg       0.79      0.79      0.79      4884
#
# Confusion matrix in fold 3:
#  [[3205  511]
#  [ 502  666]]
# For Decision Tree model, 11 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      3716
#            1       0.59      0.59      0.59      1168
#
#     accuracy                           0.80      4884
#    macro avg       0.73      0.73      0.73      4884
# weighted avg       0.80      0.80      0.80      4884
#
# Confusion matrix in fold 4:
#  [[3238  478]
#  [ 483  685]]
# For Decision Tree model, 14 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      3716
#            1       0.58      0.58      0.58      1168
#
#     accuracy                           0.80      4884
#    macro avg       0.72      0.72      0.72      4884
# weighted avg       0.80      0.80      0.80      4884
#
# Confusion matrix in fold 5:
#  [[3233  483]
#  [ 494  674]]
# For Decision Tree model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      3715
#            1       0.57      0.57      0.57      1169
#
#     accuracy                           0.79      4884
#    macro avg       0.72      0.72      0.72      4884
# weighted avg       0.79      0.79      0.79      4884
#
# Confusion matrix in fold 6:
#  [[3205  510]
#  [ 504  665]]
# For Decision Tree model, 13 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      3715
#            1       0.59      0.56      0.57      1169
#
#     accuracy                           0.80      4884
#    macro avg       0.73      0.72      0.72      4884
# weighted avg       0.80      0.80      0.80      4884
#
# Confusion matrix in fold 7:
#  [[3257  458]
#  [ 514  655]]
# For Decision Tree model, 13 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      3715
#            1       0.59      0.63      0.61      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.74      0.75      0.74      4884
# weighted avg       0.81      0.81      0.81      4884
#
# Confusion matrix in fold 8:
#  [[3200  515]
#  [ 428  741]]
# For Decision Tree model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      3715
#            1       0.57      0.62      0.59      1169
#
#     accuracy                           0.80      4884
#    macro avg       0.72      0.74      0.73      4884
# weighted avg       0.80      0.80      0.80      4884
#
# Confusion matrix in fold 9:
#  [[3170  545]
#  [ 444  725]]
# For Decision Tree model, 12 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      3715
#            1       0.62      0.65      0.64      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.75      0.76      0.76      4884
# weighted avg       0.82      0.82      0.82      4884
#
# Confusion matrix in fold 10:
#  [[3248  467]
#  [ 407  762]]
# Decision Tree Average Accuracy: 0.80
# Decision Tree Average Precision: 0.80
# Decision Tree Average Recall: 0.80
# Decision Tree Average F1 Score: 0.80
#
# ----------------------------------------------------------------------------
# For Random Forest model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      3716
#            1       0.70      0.61      0.65      1169
#
#     accuracy                           0.84      4885
#    macro avg       0.79      0.76      0.77      4885
# weighted avg       0.84      0.84      0.84      4885
#
# Confusion matrix in fold 1:
#  [[3411  305]
#  [ 459  710]]
# For Random Forest model, 14 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      3716
#            1       0.72      0.63      0.67      1169
#
#     accuracy                           0.85      4885
#    macro avg       0.80      0.77      0.79      4885
# weighted avg       0.85      0.85      0.85      4885
#
# Confusion matrix in fold 2:
#  [[3426  290]
#  [ 435  734]]
# For Random Forest model, 14 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3716
#            1       0.67      0.58      0.62      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.75      0.76      4884
# weighted avg       0.82      0.83      0.83      4884
#
# Confusion matrix in fold 3:
#  [[3376  340]
#  [ 487  681]]
# For Random Forest model, 14 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      3716
#            1       0.70      0.58      0.63      1168
#
#     accuracy                           0.84      4884
#    macro avg       0.79      0.75      0.77      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 4:
#  [[3428  288]
#  [ 494  674]]
# For Random Forest model, 14 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3716
#            1       0.67      0.56      0.61      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.74      0.75      4884
# weighted avg       0.82      0.83      0.82      4884
#
# Confusion matrix in fold 5:
#  [[3397  319]
#  [ 515  653]]
# For Random Forest model, 14 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      3715
#            1       0.70      0.57      0.63      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.79      0.75      0.76      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 6:
#  [[3430  285]
#  [ 506  663]]
# For Random Forest model, 14 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      3715
#            1       0.71      0.58      0.64      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.79      0.75      0.77      4884
# weighted avg       0.84      0.84      0.84      4884
#
# Confusion matrix in fold 7:
#  [[3441  274]
#  [ 491  678]]
# For Random Forest model, 14 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      3715
#            1       0.71      0.62      0.67      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.77      0.78      4884
# weighted avg       0.84      0.85      0.85      4884
#
# Confusion matrix in fold 8:
#  [[3422  293]
#  [ 439  730]]
# For Random Forest model, 14 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      3715
#            1       0.71      0.61      0.66      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.77      0.78      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 9:
#  [[3423  292]
#  [ 452  717]]
# For Random Forest model, 12 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.90      3715
#            1       0.72      0.62      0.67      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.77      0.79      4884
# weighted avg       0.85      0.85      0.85      4884
#
# Confusion matrix in fold 10:
#  [[3437  278]
#  [ 444  725]]
# Random Forest Average Accuracy: 0.84
# Random Forest Average Precision: 0.84
# Random Forest Average Recall: 0.84
# Random Forest Average F1 Score: 0.84
#
# ----------------------------------------------------------------------------
# For AdaBoost model, 12 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      3716
#            1       0.72      0.58      0.64      1169
#
#     accuracy                           0.84      4885
#    macro avg       0.80      0.75      0.77      4885
# weighted avg       0.84      0.84      0.84      4885
#
# Confusion matrix in fold 1:
#  [[3451  265]
#  [ 493  676]]
# For AdaBoost model, 14 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3716
#            1       0.74      0.60      0.66      1169
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.77      0.78      4885
# weighted avg       0.85      0.85      0.85      4885
#
# Confusion matrix in fold 2:
#  [[3476  240]
#  [ 473  696]]
# For AdaBoost model, 6 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      3716
#            1       0.73      0.53      0.62      1168
#
#     accuracy                           0.84      4884
#    macro avg       0.80      0.74      0.76      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 3:
#  [[3480  236]
#  [ 544  624]]
# For AdaBoost model, 10 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      3716
#            1       0.74      0.54      0.62      1168
#
#     accuracy                           0.84      4884
#    macro avg       0.80      0.74      0.76      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 4:
#  [[3492  224]
#  [ 543  625]]
# For AdaBoost model, 8 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.90      3716
#            1       0.70      0.53      0.61      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.78      0.73      0.75      4884
# weighted avg       0.83      0.83      0.83      4884
#
# Confusion matrix in fold 5:
#  [[3454  262]
#  [ 547  621]]
# For AdaBoost model, 13 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      3715
#            1       0.70      0.54      0.61      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.78      0.74      0.75      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 6:
#  [[3443  272]
#  [ 533  636]]
# For AdaBoost model, 13 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      3715
#            1       0.74      0.56      0.64      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.75      0.77      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 7:
#  [[3483  232]
#  [ 516  653]]
# For AdaBoost model, 12 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      3715
#            1       0.75      0.62      0.68      1169
#
#     accuracy                           0.86      4884
#    macro avg       0.82      0.78      0.79      4884
# weighted avg       0.85      0.86      0.85      4884
#
# Confusion matrix in fold 8:
#  [[3472  243]
#  [ 449  720]]
# For AdaBoost model, 14 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3715
#            1       0.75      0.60      0.67      1169
#
#     accuracy                           0.86      4884
#    macro avg       0.82      0.77      0.79      4884
# weighted avg       0.85      0.86      0.85      4884
#
# Confusion matrix in fold 9:
#  [[3476  239]
#  [ 462  707]]
# For AdaBoost model, 13 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3715
#            1       0.75      0.58      0.66      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.82      0.76      0.78      4884
# weighted avg       0.85      0.85      0.85      4884
#
# Confusion matrix in fold 10:
#  [[3493  222]
#  [ 490  679]]
# AdaBoost Average Accuracy: 0.85
# AdaBoost Average Precision: 0.84
# AdaBoost Average Recall: 0.85
# AdaBoost Average F1 Score: 0.84
#
# ----------------------------------------------------------------------------
# For GradientBoost model, 13 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3716
#            1       0.74      0.59      0.66      1169
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.76      0.78      4885
# weighted avg       0.85      0.85      0.85      4885
#
# Confusion matrix in fold 1:
#  [[3476  240]
#  [ 474  695]]
# For GradientBoost model, 12 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      3716
#            1       0.75      0.60      0.66      1169
#
#     accuracy                           0.86      4885
#    macro avg       0.82      0.77      0.79      4885
# weighted avg       0.85      0.86      0.85      4885
#
# Confusion matrix in fold 2:
#  [[3485  231]
#  [ 472  697]]
# For GradientBoost model, 14 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      3716
#            1       0.72      0.59      0.65      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.76      0.77      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 3:
#  [[3450  266]
#  [ 482  686]]
# For GradientBoost model, 11 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91      3716
#            1       0.75      0.55      0.64      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.81      0.75      0.77      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 4:
#  [[3506  210]
#  [ 523  645]]
# For GradientBoost model, 13 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      3716
#            1       0.73      0.56      0.63      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.75      0.77      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 5:
#  [[3473  243]
#  [ 513  655]]
# For GradientBoost model, 14 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      3715
#            1       0.74      0.56      0.63      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.75      0.77      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 6:
#  [[3482  233]
#  [ 518  651]]
# For GradientBoost model, 11 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      3715
#            1       0.77      0.57      0.65      1169
#
#     accuracy                           0.86      4884
#    macro avg       0.82      0.76      0.78      4884
# weighted avg       0.85      0.86      0.85      4884
#
# Confusion matrix in fold 7:
#  [[3515  200]
#  [ 507  662]]
# For GradientBoost model, 12 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      3715
#            1       0.78      0.62      0.69      1169
#
#     accuracy                           0.87      4884
#    macro avg       0.83      0.78      0.80      4884
# weighted avg       0.86      0.87      0.86      4884
#
# Confusion matrix in fold 8:
#  [[3508  207]
#  [ 442  727]]
# For GradientBoost model, 11 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      3715
#            1       0.77      0.61      0.69      1169
#
#     accuracy                           0.86      4884
#    macro avg       0.83      0.78      0.80      4884
# weighted avg       0.86      0.86      0.86      4884
#
# Confusion matrix in fold 9:
#  [[3506  209]
#  [ 451  718]]
# For GradientBoost model, 10 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      3715
#            1       0.78      0.62      0.69      1169
#
#     accuracy                           0.87      4884
#    macro avg       0.84      0.78      0.80      4884
# weighted avg       0.86      0.87      0.86      4884
#
# Confusion matrix in fold 10:
#  [[3516  199]
#  [ 443  726]]
# GradientBoost Average Accuracy: 0.86
# GradientBoost Average Precision: 0.85
# GradientBoost Average Recall: 0.86
# GradientBoost Average F1 Score: 0.85
#
# ----------------------------------------------------------------------------
# For XGBoost model, 12 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      3716
#            1       0.71      0.64      0.68      1169
#
#     accuracy                           0.85      4885
#    macro avg       0.80      0.78      0.79      4885
# weighted avg       0.85      0.85      0.85      4885
#
# Confusion matrix in fold 1:
#  [[3416  300]
#  [ 418  751]]
# For XGBoost model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      3716
#            1       0.73      0.67      0.70      1169
#
#     accuracy                           0.86      4885
#    macro avg       0.82      0.80      0.81      4885
# weighted avg       0.86      0.86      0.86      4885
#
# Confusion matrix in fold 2:
#  [[3432  284]
#  [ 386  783]]
# For XGBoost model, 13 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      3716
#            1       0.70      0.64      0.67      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.78      0.79      4884
# weighted avg       0.84      0.85      0.85      4884
#
# Confusion matrix in fold 3:
#  [[3400  316]
#  [ 423  745]]
# For XGBoost model, 14 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      3716
#            1       0.74      0.60      0.66      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.81      0.77      0.78      4884
# weighted avg       0.85      0.85      0.85      4884
#
# Confusion matrix in fold 4:
#  [[3469  247]
#  [ 469  699]]
# For XGBoost model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      3716
#            1       0.73      0.61      0.67      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.81      0.77      0.79      4884
# weighted avg       0.85      0.85      0.85      4884
#
# Confusion matrix in fold 5:
#  [[3448  268]
#  [ 451  717]]
# For XGBoost model, 11 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      3715
#            1       0.71      0.61      0.66      1169
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.76      0.78      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 6:
#  [[3432  283]
#  [ 461  708]]
# For XGBoost model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      3715
#            1       0.74      0.62      0.68      1169
#
#     accuracy                           0.86      4884
#    macro avg       0.82      0.78      0.79      4884
# weighted avg       0.85      0.86      0.85      4884
#
# Confusion matrix in fold 7:
#  [[3466  249]
#  [ 442  727]]
# For XGBoost model, 13 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91      3715
#            1       0.76      0.65      0.70      1169
#
#     accuracy                           0.87      4884
#    macro avg       0.83      0.79      0.81      4884
# weighted avg       0.86      0.87      0.86      4884
#
# Confusion matrix in fold 8:
#  [[3470  245]
#  [ 406  763]]
# For XGBoost model, 11 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      3715
#            1       0.77      0.66      0.71      1169
#
#     accuracy                           0.87      4884
#    macro avg       0.83      0.80      0.81      4884
# weighted avg       0.87      0.87      0.87      4884
#
# Confusion matrix in fold 9:
#  [[3479  236]
#  [ 400  769]]
# For XGBoost model, 12 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      3715
#            1       0.79      0.67      0.72      1169
#
#     accuracy                           0.88      4884
#    macro avg       0.84      0.81      0.82      4884
# weighted avg       0.87      0.88      0.87      4884
#
# Confusion matrix in fold 10:
#  [[3503  212]
#  [ 389  780]]
# XGBoost Average Accuracy: 0.86
# XGBoost Average Precision: 0.85
# XGBoost Average Recall: 0.86
# XGBoost Average F1 Score: 0.86
#
# ----------------------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001244 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 684
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 681
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 674
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000936 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 649
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000831 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 649
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000978 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 649
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# For LightGBM model, 11 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      3716
#            1       0.72      0.64      0.68      1169
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.78      0.79      4885
# weighted avg       0.85      0.85      0.85      4885
#
# Confusion matrix in fold 1:
#  [[3432  284]
#  [ 426  743]]
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001469 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# [LightGBM] [Info] Number of positive: 10518, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001249 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 43957, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239279 -> initscore=-1.156635
# [LightGBM] [Info] Start training from score -1.156635
# For LightGBM model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      3716
#            1       0.73      0.65      0.69      1169
#
#     accuracy                           0.86      4885
#    macro avg       0.81      0.79      0.80      4885
# weighted avg       0.86      0.86      0.86      4885
#
# Confusion matrix in fold 2:
#  [[3441  275]
#  [ 411  758]]
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001257 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 681
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001179 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001039 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# For LightGBM model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      3716
#            1       0.70      0.63      0.66      1168
#
#     accuracy                           0.85      4884
#    macro avg       0.80      0.77      0.78      4884
# weighted avg       0.84      0.85      0.84      4884
#
# Confusion matrix in fold 3:
#  [[3409  307]
#  [ 437  731]]
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001034 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 653
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239297 -> initscore=-1.156540
# [LightGBM] [Info] Start training from score -1.156540
# [LightGBM] [Info] Number of positive: 10519, number of negative: 33439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000972 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 653
# ...
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 671
# [LightGBM] [Info] Number of data points in the train set: 43958, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239274 -> initscore=-1.156665
# [LightGBM] [Info] Start training from score -1.156665
# For LightGBM model, 14 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      3715
#            1       0.79      0.65      0.72      1169
#
#     accuracy                           0.88      4884
#    macro avg       0.85      0.80      0.82      4884
# weighted avg       0.87      0.88      0.87      4884
#
# Confusion matrix in fold 10:
#  [[3519  196]
#  [ 409  760]]
# LightGBM Average Accuracy: 0.86
# LightGBM Average Precision: 0.85
# LightGBM Average Recall: 0.86
# LightGBM Average F1 Score: 0.86
#
# ----------------------------------------------------------------------------
# For Naive Bayes model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88      3716
#            1       0.66      0.42      0.51      1169
#
#     accuracy                           0.81      4885
#    macro avg       0.75      0.68      0.70      4885
# weighted avg       0.79      0.81      0.79      4885
#
# Confusion matrix in fold 1:
#  [[3457  259]
#  [ 674  495]]
# For Naive Bayes model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      3716
#            1       0.64      0.38      0.48      1169
#
#     accuracy                           0.80      4885
#    macro avg       0.73      0.66      0.68      4885
# weighted avg       0.78      0.80      0.78      4885
#
# Confusion matrix in fold 2:
#  [[3467  249]
#  [ 726  443]]
# For Naive Bayes model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88      3716
#            1       0.67      0.43      0.52      1168
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.68      0.70      4884
# weighted avg       0.80      0.81      0.80      4884
#
# Confusion matrix in fold 3:
#  [[3474  242]
#  [ 670  498]]
# For Naive Bayes model, 12 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3716
#            1       0.67      0.38      0.48      1168
#
#     accuracy                           0.81      4884
#    macro avg       0.75      0.66      0.68      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 4:
#  [[3498  218]
#  [ 728  440]]
# For Naive Bayes model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      3716
#            1       0.64      0.39      0.48      1168
#
#     accuracy                           0.80      4884
#    macro avg       0.73      0.66      0.68      4884
# weighted avg       0.78      0.80      0.78      4884
#
# Confusion matrix in fold 5:
#  [[3461  255]
#  [ 715  453]]
# For Naive Bayes model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3715
#            1       0.67      0.40      0.50      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.75      0.67      0.69      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 6:
#  [[3485  230]
#  [ 701  468]]
# For Naive Bayes model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      3715
#            1       0.67      0.40      0.50      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.75      0.67      0.69      4884
# weighted avg       0.79      0.81      0.79      4884
#
# Confusion matrix in fold 7:
#  [[3490  225]
#  [ 704  465]]
# For Naive Bayes model, 7 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88      3715
#            1       0.63      0.64      0.63      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.76      0.76      4884
# weighted avg       0.82      0.82      0.82      4884
#
# Confusion matrix in fold 8:
#  [[3282  433]
#  [ 426  743]]
# For Naive Bayes model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      3715
#            1       0.60      0.59      0.59      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.73      0.73      0.73      4884
# weighted avg       0.80      0.81      0.81      4884
#
# Confusion matrix in fold 9:
#  [[3253  462]
#  [ 485  684]]
# For Naive Bayes model, 5 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      3715
#            1       0.69      0.38      0.49      1169
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.66      0.69      4884
# weighted avg       0.80      0.81      0.79      4884
#
# Confusion matrix in fold 10:
#  [[3518  197]
#  [ 722  447]]
# Naive Bayes Average Accuracy: 0.81
# Naive Bayes Average Precision: 0.80
# Naive Bayes Average Recall: 0.81
# Naive Bayes Average F1 Score: 0.79
#
# ----------------------------------------------------------------------------
# For KNN model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      3716
#            1       0.65      0.46      0.54      1169
#
#     accuracy                           0.81      4885
#    macro avg       0.75      0.69      0.71      4885
# weighted avg       0.80      0.81      0.80      4885
#
# Confusion matrix in fold 1:
#  [[3420  296]
#  [ 628  541]]
# For KNN model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      3716
#            1       0.69      0.46      0.55      1169
#
#     accuracy                           0.82      4885
#    macro avg       0.77      0.70      0.72      4885
# weighted avg       0.81      0.82      0.81      4885
#
# Confusion matrix in fold 2:
#  [[3472  244]
#  [ 632  537]]
# For KNN model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      3716
#            1       0.67      0.47      0.55      1168
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.70      0.72      4884
# weighted avg       0.80      0.82      0.81      4884
#
# Confusion matrix in fold 3:
#  [[3446  270]
#  [ 623  545]]
# For KNN model, 12 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      3716
#            1       0.72      0.46      0.56      1168
#
#     accuracy                           0.83      4884
#    macro avg       0.79      0.70      0.73      4884
# weighted avg       0.82      0.83      0.81      4884
#
# Confusion matrix in fold 4:
#  [[3509  207]
#  [ 628  540]]
# For KNN model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88      3716
#            1       0.68      0.42      0.52      1168
#
#     accuracy                           0.81      4884
#    macro avg       0.76      0.68      0.70      4884
# weighted avg       0.80      0.81      0.80      4884
#
# Confusion matrix in fold 5:
#  [[3483  233]
#  [ 676  492]]
# For KNN model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.93      0.88      3715
#            1       0.67      0.46      0.55      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.69      0.71      4884
# weighted avg       0.80      0.82      0.80      4884
#
# Confusion matrix in fold 6:
#  [[3446  269]
#  [ 630  539]]
# For KNN model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      3715
#            1       0.70      0.46      0.55      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.77      0.70      0.72      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 7:
#  [[3488  227]
#  [ 637  532]]
# For KNN model, 7 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      3715
#            1       0.73      0.54      0.62      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.80      0.74      0.76      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 8:
#  [[3478  237]
#  [ 543  626]]
# For KNN model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      3715
#            1       0.68      0.57      0.62      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.78      0.74      0.76      4884
# weighted avg       0.83      0.83      0.83      4884
#
# Confusion matrix in fold 9:
#  [[3406  309]
#  [ 501  668]]
# For KNN model, 5 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      3715
#            1       0.74      0.51      0.60      1169
#
#     accuracy                           0.84      4884
#    macro avg       0.80      0.73      0.75      4884
# weighted avg       0.83      0.84      0.83      4884
#
# Confusion matrix in fold 10:
#  [[3499  216]
#  [ 569  600]]
# KNN Average Accuracy: 0.82
# KNN Average Precision: 0.81
# KNN Average Recall: 0.82
# KNN Average F1 Score: 0.81
#
# ----------------------------------------------------------------------------
# For Bagging model, 14 features have been selected in fold 1 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      3716
#            1       0.68      0.56      0.61      1169
#
#     accuracy                           0.83      4885
#    macro avg       0.78      0.74      0.75      4885
# weighted avg       0.82      0.83      0.83      4885
#
# Confusion matrix in fold 1:
#  [[3413  303]
#  [ 519  650]]
# For Bagging model, 13 features have been selected in fold 2 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3716
#            1       0.66      0.57      0.61      1169
#
#     accuracy                           0.83      4885
#    macro avg       0.76      0.74      0.75      4885
# weighted avg       0.82      0.83      0.82      4885
#
# Confusion matrix in fold 2:
#  [[3370  346]
#  [ 504  665]]
# For Bagging model, 12 features have been selected in fold 3 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      3716
#            1       0.64      0.52      0.58      1168
#
#     accuracy                           0.82      4884
#    macro avg       0.75      0.72      0.73      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 3:
#  [[3376  340]
#  [ 555  613]]
# For Bagging model, 12 features have been selected in fold 4 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      3716
#            1       0.66      0.53      0.59      1168
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.72      0.74      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 4:
#  [[3402  314]
#  [ 554  614]]
# For Bagging model, 11 features have been selected in fold 5 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      3716
#            1       0.63      0.55      0.59      1168
#
#     accuracy                           0.82      4884
#    macro avg       0.75      0.72      0.73      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 5:
#  [[3347  369]
#  [ 529  639]]
# For Bagging model, 12 features have been selected in fold 6 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89      3715
#            1       0.65      0.54      0.59      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.73      0.74      4884
# weighted avg       0.81      0.82      0.82      4884
#
# Confusion matrix in fold 6:
#  [[3373  342]
#  [ 532  637]]
# For Bagging model, 12 features have been selected in fold 7 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      3715
#            1       0.66      0.51      0.58      1169
#
#     accuracy                           0.82      4884
#    macro avg       0.76      0.72      0.73      4884
# weighted avg       0.81      0.82      0.81      4884
#
# Confusion matrix in fold 7:
#  [[3403  312]
#  [ 567  602]]
# For Bagging model, 7 features have been selected in fold 8 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3715
#            1       0.67      0.58      0.62      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.75      0.76      4884
# weighted avg       0.83      0.83      0.83      4884
#
# Confusion matrix in fold 8:
#  [[3384  331]
#  [ 490  679]]
# For Bagging model, 13 features have been selected in fold 9 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      3715
#            1       0.68      0.56      0.61      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.74      0.75      4884
# weighted avg       0.82      0.83      0.83      4884
#
# Confusion matrix in fold 9:
#  [[3403  312]
#  [ 513  656]]
# For Bagging model, 5 features have been selected in fold 10 where
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      3715
#            1       0.68      0.56      0.62      1169
#
#     accuracy                           0.83      4884
#    macro avg       0.77      0.74      0.75      4884
# weighted avg       0.82      0.83      0.83      4884
#
# Confusion matrix in fold 10:
#  [[3399  316]
#  [ 509  660]]
# Bagging Average Accuracy: 0.82
# Bagging Average Precision: 0.82
# Bagging Average Recall: 0.82
# Bagging Average F1 Score: 0.82
#
# ----------------------------------------------------------------------------

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                            Accuracy  Precision    Recall  F1 Score
# Logistic Regression        0.811822   0.797523  0.811822  0.794325
# Support Vector Classifier  0.832869   0.822994  0.832869  0.818763
# Decision Tree              0.801626   0.803318  0.801626  0.802365
# Random Forest              0.842635   0.836275  0.842635  0.838021
# AdaBoost                   0.846751   0.839177  0.846751  0.839635
# GradientBoost              0.855391   0.848832  0.855391  0.848786
# XGBoost                    0.859035   0.854142  0.859035  0.855308
# LightGBM                   0.859609   0.854462  0.859609  0.855486
# Naive Bayes                0.809160   0.796251  0.809160  0.794261
# KNN                        0.824434   0.812969  0.824434  0.812489
# Bagging                    0.824802   0.816545  0.824802  0.818914
